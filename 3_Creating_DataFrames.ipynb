# %% [markdown]
# <a href="https://colab.research.google.com/github/Tarun-pandit/Data_Science_practice/blob/DATA_ANALYSIS_USING_PANDAS/3_Creating_DataFrames.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## From Python Lists
# This cell creates a pandas DataFrame from a Python list of lists.
import pandas as pd

data = [
    ["Alice", 25],
    ["Bob", 30],
    ["Charlie", 35]
]

df = pd.DataFrame(data, columns=["Name", "Age"])
print(df)
# Out:
#       Name  Age
# 0    Alice   25
# 1      Bob   30
# 2  Charlie   35

# %%
## From Dictionary of Lists
##Most common and readable format:
# This cell creates a pandas DataFrame from a Python dictionary where keys are column names and values are lists of data.
data = {
    "Name": ["Alice", "Bob", "Charlie"],
    "Age": [25, 30, 35]
}

df = pd.DataFrame(data)
print(df)
# Out:
#       Name  Age
# 0    Alice   25
# 1      Bob   30
# 2  Charlie   35

# %%
## From NumPy Arrays
# This cell creates a pandas DataFrame from a NumPy array.
import numpy as np

arr = np.array([[1, 2], [3, 4]])
df = pd.DataFrame(arr, columns=["A", "B"])
print(df)
# Out:
#    A  B
# 0  1  2
# 1  3  4

# %%
# This cell reads data from a CSV file into a pandas DataFrame.
df = pd.read_csv("1745500125912-data.csv")
df
# Out:
#                  Actor                      Film  Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 2           Aamir Khan                    Dangal  2016        Biography
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
#
#     BoxOffice(INR Crore)  IMDb
# ...

# %%
# This cell reads data from an Excel file into a pandas DataFrame.
df = pd.read_excel("/content/Cognizant campus hiring 2026  (Responses) (1).xlsx")
df
# Out:
#       Sno.        Students Name  Roll Number  \
# 0        1         Ayush Ponia    2215800004
# 1        2       Nishchay gaur    2215300029
# 2        3            Ansh Garg   2215000281
# 3        4       Rishabh Shukla   2215001450
# 4        5  Krishanangi Agrawal   2215000948
# ...    ...                  ...          ...
# 1620  1621          shalu singh   2215001630
# 1621  1622  priyanshi choudhary   2215001338
# 1622  1623      Jeet Thakurela    2215800012
# 1623  1624       Mradul Sharma    2215500099
# 1624  1625     Vedanshu Maurya    2215001933
#
#                                 Email Id Phone Number  Course \n  \
# 0           ayush.ponia_cs.h22@gla.ac.in   7078696083  B.tech CS
# 1               nishchaygaur40@gmail.com   9758925637  B.tech CS
# 2               ansh.garg_cs22@gla.ac.in   7248848020  B.tech CS
# 3          rishabh.shukla_cs22@gla.ac.in   7394882192  B.tech CS
# 4      krishnangi.agrawal_cs22@gla.ac.in   6398907210  B.tech CS
# ...

# %%
# This cell reads data from a JSON file into a pandas DataFrame.
df = pd.read_json("/content/data2.json")
df
# Out:
#                                                users  \
# 0  {'id': 1, 'name': 'Amit', 'friends': [2, 3], '...
# 1  {'id': 2, 'name': 'Priya', 'friends': [1, 4], ...
# 2  {'id': 3, 'name': '', 'friends': [1], 'liked_p...
# 3  {'id': 4, 'name': 'Sara', 'friends': [2, 2], '...
# 4  {'id': 5, 'name': 'Amit', 'friends': [], 'like...
#
#                                              pages
# 0         {'id': 101, 'name': 'Python Developers'}
# 1  {'id': 102, 'name': 'Data Science Enthusiasts'}
# 2         {'id': 103, 'name': 'AI & ML Community'}
# 3               {'id': 104, 'name': 'Web Dev Hub'}
# 4           {'id': 104, 'name': 'Web Development'}

# %%
# This cell reads data from a CSV file hosted on a URL into a pandas DataFrame.
url = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/tips.csv"
df = pd.read_csv(url)
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# **`EDA (Exploratory Data Analysis)`**
#
# Exploratory Data Analysis (EDA) is an essential first step in any data science project.
#
# It involves taking a deep look at the dataset to understand its structure, spot patterns, identify anomalies, and uncover relationships between variables. This process includes generating summary statistics, checking for missing or duplicate data, and creating visualizations like histograms, box plots, and scatter plots. The goal of EDA is to get a clear picture of what the data is telling you before applying any analysis or machine learning models.
#
# By exploring the data thoroughly, you can make better decisions about how to clean, transform, and model it effectively.
#
# Once your DataFrame is ready, run these to understand your data:

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    object
#  3   smoker      244 non-null    object
#  4   day         244 non-null    object
#  5   time        244 non-null    object
#  6   size        244 non-null    int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.5+ KB

# %%
df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
df.shape
# Out:
# (244, 7)

# %% [markdown]
# **Summary**
# * You can create DataFrames from lists, dicts, arrays, files, web, and SQL
# * Use .head(), .info(), .describe() to quickly explore any dataset
