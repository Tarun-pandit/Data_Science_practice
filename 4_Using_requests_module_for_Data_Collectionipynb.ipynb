# %% [markdown]
# <a href="https://colab.research.google.com/github/Tarun-pandit/Data_Science_practice/blob/Data-Collection-Techniques/4_Using_requests_module_for_Data_Collectionipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Using requests module for Data Collection
#
# Today we will see how to scrape websites and use requests module to download the raw html of a webpage. In this section we can safely use https://quotes.toscrape.com/ and https://books.toscrape.com/ for scraping demos
#
# 1.  **What is requests?**
#     *   `requests` is a Python library used to send HTTP requests easily.
#     *   It allows you to fetch the content of a webpage programmatically.
#     *   It is commonly used as the first step before parsing HTML with BeautifulSoup.

# %% [markdown]
# 2.  **Installing requests**
#     *   To install requests, run:

# %%
pip install requests

# %% [markdown]
# 3. Sending a Basic GET Request
# Example

# %%
import requests

url = "https://books.toscrape.com/catalogue/category/books_1/index.html"
response = requests.get(url)

# Print the HTML content
print(response.text)
# Out:
# <!DOCTYPE html>
# <!--[if lt IE 7]>      <html lang="en-us" class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]-->
# <!--[if IE 7]>         <html lang="en-us" class="no-js lt-ie9 lt-ie8"> <![endif]-->
# <!--[if IE 8]>         <html lang="en-us" class="no-js lt-ie9"> <![endif]-->
# <!--[if gt IE 8]><!--> <html lang="en-us" class="no-js"> <!--<![endif]-->
#     <head>
#         <title>
#     Books |
#      Books to Scrape - Sandbox
#
# </title>
#
#         <meta http-equiv="content-type" content="text/html; charset=UTF-8" />
#         <meta name="created" content="24th Jun 2016 09:29" />
#         <meta name="description" content="
#
# " />
#         <meta name="viewport" content="width=device-width" />
#         <meta name="robots" content="NOARCHIVE,NOCACHE" />
#
#         <!-- Le HTML5 shim, for IE6-8 support of HTML elements -->
#         <!--[if lt IE 9]>
#         <script src="//html5shim.googlecode.com/svn/trunk/html5.js"></script>
#         <![endif]-->
#
#
# ...

# %%
for i in range(1,51):
  response = requests.get(url)
  with open(f"books_category_page{i}.html", "w", encoding="utf-8") as f:
      f.write(response.text)
      print(f"Downloaded page {i} saved successfully!")
# Out:
# Downloaded page 1 saved successfully!
# Downloaded page 2 saved successfully!
# Downloaded page 3 saved successfully!
# Downloaded page 4 saved successfully!
# Downloaded page 5 saved successfully!
# Downloaded page 6 saved successfully!
# Downloaded page 7 saved successfully!
# Downloaded page 8 saved successfully!
# Downloaded page 9 saved successfully!
# Downloaded page 10 saved successfully!
# Downloaded page 11 saved successfully!
# Downloaded page 12 saved successfully!
# Downloaded page 13 saved successfully!
# Downloaded page 14 saved successfully!
# Downloaded page 15 saved successfully!
# Downloaded page 16 saved successfully!
# Downloaded page 17 saved successfully!
# Downloaded page 18 saved successfully!
# Downloaded page 19 saved successfully!
# Downloaded page 20 saved successfully!
# Downloaded page 21 saved successfully!
# Downloaded page 22 saved successfully!
# Downloaded page 23 saved successfully!
# Downloaded page 24 saved successfully!
# ...

# %% [markdown]
# 4. Checking the Response Status
# Always check if the request was successful:

# %%
print(response.status_code)
# Out:
# 200

# %% [markdown]
# Common Status Codes
# * 200: OK (Success)
# * 404: Not Found
# * 403: Forbidden
# * 500: Internal Server Error
#
# Good practice:

# %% [markdown]
# Common Status Codes
# * 200: OK (Success)
# * 404: Not Found
# * 403: Forbidden
# * 500: Internal Server Error
#
# Good practice:

# %%
if response.status_code == 200:
    print("Page fetched successfully!")
else:
    print("Failed to fetch the page.")
# Out:
# Page fetched successfully!

# %% [markdown]
# **5**. Important Response Properties
#
# | Property        | Description                     |
# |-----------------|---------------------------------|
# | `response.text` | HTML content as Unicode text    |
# | `response.content` | Raw bytes of the response       |
# | `response.status_code` | HTTP status code                |
# | `response.headers` | Metadata like content-type, server info |

# %% [markdown]
# **6**. Adding Headers to Mimic a Browser
# Sometimes websites block automated requests. Adding a User-Agent header helps the request look like it is coming from a real browser.

# %%
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64)"
}

response = requests.get(url, headers=headers)

# %% [markdown]
# **7**. Handling Connection Errors
# Wrap your request in a try-except block to handle errors gracefully:

# %%
try:
    response = requests.get(url, timeout=5)
    response.raise_for_status()  # Raises an HTTPError for bad responses
    print(response.text)
except requests.exceptions.RequestException as e:
    print(f"An error occurred: {e}")
# Out:
# <!DOCTYPE html>
# <!--[if lt IE 7]>      <html lang="en-us" class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]-->
# <!--[if IE 7]>         <html lang="en-us" class="no-js lt-ie9 lt-ie8"> <![endif]-->
# <!--[if IE 8]>         <html lang="en-us" class="no-js lt-ie9"> <![endif]-->
# <!--[if gt IE 8]><!--> <html lang="en-us" class="no-js"> <!--<![endif]-->
#     <head>
#         <title>
#     Books |
#      Books to Scrape - Sandbox
#
# </title>
#
#         <meta http-equiv="content-type" content="text/html; charset=UTF-8" />
#         <meta name="created" content="24th Jun 2016 09:29" />
#         <meta name="description" content="
#
# " />
#         <meta name="viewport" content="width=device-width" />
#         <meta name="robots" content="NOARCHIVE,NOCACHE" />
#
#         <!-- Le HTML5 shim, for IE6-8 support of HTML elements -->
#         <!--[if lt IE 9]>
#         <script src="//html5shim.googlecode.com/svn/trunk/html5.js"></script>
#         <![endif]-->
#
#
# ...

# %% [markdown]
# **8**. Best Practices for Fetching Pages
# * Always check the HTTP status code.
# * Use proper headers to mimic a browser.
# * Set a timeout to avoid hanging indefinitely.
# * Respect the website by not making too many rapid requests.

# %% [markdown]
# **9**. Summary
# * requests makes it simple to fetch web pages using Python.
# * It is the starting point for most web scraping workflows.
# * Combining requests with BeautifulSoup allows for powerful data extraction.
